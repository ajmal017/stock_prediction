# %% [markdown]
# #Tasks
#
#
# Create a reinforcement learning agent to predict stock prices
#
# *   import dependencies
# *   import dataset
# *   Define agent algorithm
# *   make predictions
# *   plot predictions

# %% [markdown]
# #This is to install yfinance api to automatically download

# %%
#matrix math & data pre-processing
import numpy as np

#for data formatting
import pandas as pd

#for plotting
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Requirement already up-to-date: yfinance in /usr/local/lib/python3.6/dist-packages (0.1.45)
# ...

# %%
from google.colab import drive
drive.mount('drive',force_remount=True)

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf

yf.pdr_override()
df_full = pdr.get_data_yahoo("Z74.SI", start="2018-01-01").reset_index()
df_full.to_csv('Z74.SI.csv',index=False)
df_full.head(10)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2018-01-02  3.58  3.61  3.57   3.60   3.227661  19718200
# 1 2018-01-03  3.60  3.61  3.59   3.59   3.218695  15371400
# 2 2018-01-04  3.61  3.61  3.59   3.61   3.236627  29020100
# 3 2018-01-05  3.61  3.62  3.60   3.60   3.227661  25692943
# 4 2018-01-08  3.62  3.63  3.61   3.63   3.254558  11292000
# 5 2018-01-09  3.63  3.65  3.62   3.63   3.254558  21320100
# 6 2018-01-10  3.63  3.63  3.60   3.62   3.245592  16108800
# 7 2018-01-11  3.62  3.63  3.61   3.61   3.236627  12114800
# 8 2018-01-12  3.62  3.63  3.59   3.60   3.227661  27801600
# 9 2018-01-15  3.61  3.61  3.59   3.60   3.227661  18555600

# %%
df_full = pd.read_csv('Z74.SI.csv')

# %% [markdown]
# #Minimum to understand is Turtle Trading Agent
# #Really intertesting is policy gradient agent
#
# These three are not learning agents. These are predefined threadshold value. Based on buy / sell predefined threadshold value.
#
# * Turtle Trading Agent
# * Moving Average Agent
# * Singal Rolling Agent
#
# --pure reinforcement learning
#
# * Policy gradient agent
# * Q-learning agent
#
# --Evolutionary
#
# * Evolution Strategy Agent
#
# --Deep Reinforcement Learning
#
# * Double Q-learning agent
# * Recurrent Q-learning agent
# * Double Recurrent Q-learning agent
# * Duel Q-learning agent
# * Double Duel Q-learning agent
# * Duel Recurrent Q-learning agent
# * Double Duel Recurrent Q-learning agent
# * Actor-critic agent
# * Actor-critic Duel agent
# * Actor-critic Recurrent agent
# * Actor-critic Duel Recurrent agent
# * Curiosity Q-learning agent
# * Recurrent Curiosity Q-learning agent
# * Duel Curiosity Q-learning agent
# * Neuro-evolution agent
# * Neuro-evolution with Novelty search agent
# * ABCD strategy agent
# * Deep Evolution Strategy

# %%
df= df_full.copy()
name = 'Turtle Trading Agent'
count = int(np.ceil(len(df) * 0.1))
signals = pd.DataFrame(index=df.index)
signals['signal'] = 0.0
signals['trend'] = df['Close']
signals['RollingMax'] = (signals.trend.shift(1).rolling(count).max())
signals['RollingMin'] = (signals.trend.shift(1).rolling(count).min())
signals.loc[signals['RollingMax'] < signals.trend, 'signal'] = -1
signals.loc[signals['RollingMin'] > signals.trend, 'signal'] = 1
signals
# Out:
#      signal  trend  RollingMax  RollingMin
# 0       0.0   3.60         NaN         NaN
# 1       0.0   3.59         NaN         NaN
# 2       0.0   3.61         NaN         NaN
# 3       0.0   3.60         NaN         NaN
# 4       0.0   3.63         NaN         NaN
# 5       0.0   3.63         NaN         NaN
# 6       0.0   3.62         NaN         NaN
# 7       0.0   3.61         NaN         NaN
# 8       0.0   3.60         NaN         NaN
# 9       0.0   3.60         NaN         NaN
# 10      0.0   3.61         NaN         NaN
# 11      0.0   3.59         NaN         NaN
# 12      0.0   3.59         NaN         NaN
# 13      0.0   3.60         NaN         NaN
# 14      0.0   3.62         NaN         NaN
# 15      0.0   3.61         NaN         NaN
# 16      0.0   3.64         NaN         NaN
# 17      0.0   3.62         NaN         NaN
# 18      0.0   3.60         NaN         NaN
# 19      0.0   3.61         NaN         NaN
# 20      0.0   3.57         NaN         NaN
# ...

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    for i in range(real_movement.shape[0] - int(0.025 * len(df))):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
            
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, signals['signal'])
# Out:
# day 43: buy 1 units at price 3.310000, total balance 9996.690000
# day 82, sell 1 units at price 3.520000, investment 6.344411 %, total balance 10000.210000,
# day 88: cannot sell anything, inventory 0
# day 90: cannot sell anything, inventory 0
# day 102: buy 1 units at price 3.280000, total balance 9996.930000
# day 104: buy 1 units at price 3.250000, total balance 9993.680000
# day 109: buy 1 units at price 3.230000, total balance 9990.450000
# day 112: buy 1 units at price 3.220000, total balance 9987.230000
# day 113: buy 1 units at price 3.190000, total balance 9984.040000
# day 115: buy 1 units at price 3.180000, total balance 9980.860000
# day 116: buy 1 units at price 3.170000, total balance 9977.690000
# day 117: buy 1 units at price 3.160000, total balance 9974.530000
# day 118: buy 1 units at price 3.120000, total balance 9971.410000
# day 119: buy 1 units at price 3.110000, total balance 9968.300000
# day 121: buy 1 units at price 3.100000, total balance 9965.200000
# ...

# %% [markdown]
# # alpaca api
# Build and trade with real-time market data for free

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# #Additional Learning especially for Q Learning (the best explanation)
# https://simoninithomas.github.io/Deep_reinforcement_learning_Course/
